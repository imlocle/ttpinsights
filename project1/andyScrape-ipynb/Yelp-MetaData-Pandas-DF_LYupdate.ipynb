# %%
# yelp scraping project
import requests
import json
import pandas as pd

from bs4 import BeautifulSoup
import requests
from splinter import Browser
from selenium import webdriver

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

import pandas as pd
import re

# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# create input variables

search = input("What would you like to search: ")
zipcode = input("Where would you like to search: ")

# changed where to Where
# created space after search:" to search: "
# Out:
# What would you like to search: barbershop
# Where would you like to search: 92780

# %%
# default web search to concatenate
default = "https://www.yelp.com/search?find_desc="
locationUrl = "&find_loc="
end = "&start="

# empty lists to append to
url = []
business_name = []
business_category = []
yelp_rating = []
review_count = []
price_range = []
price_category = []

address = []
phone = []
website = []

# new data
review_content = []

# list range
myList = range(0, 11)

# %%
# function to search input parameters on Yelp
def search_yelp(search, zipcode):
    
    keyword = search;
    zipcode = zipcode;
    
    for e in myList[::10]:
        
        query_url = f"{default}{search}{locationUrl}{zipcode}{end}{e}";
        response = requests.get(query_url)
        soup = BeautifulSoup(response.text, 'html.parser');
        
        for link in soup.find_all('a', class_="biz-name"):
            if link.get('href').startswith('/adredir?'):
                continue
            else:
                url.append("https://www.yelp.com"+link.get('href'))

# %%
# function to scrape yelp data on each page
def scrape_yelp(url):
    for i in url:
        try:
            response = requests.get(i)
            soup = BeautifulSoup(response.text, 'html.parser')
            
            
            business_name.append(soup.find('h1', attrs={'class':'biz-page-title'}).text.strip())
            business_category.append(soup.find(attrs={'class': 'category-str-list'}).text.strip())
            yelp_rating.append(soup.find(attrs={"class":"i-stars"})["title"])
            review_count.append(soup.find(attrs={'class': 'review-count rating-qualifier'}).text.strip())
            price_range.append(soup.find(attrs={'class': 'business-attribute price-range'}).text.strip())
            price_category.append(soup.find(attrs={'class': 'nowrap price-description'}).text.strip())
            address.append(soup.find(attrs={'class': 'street-address'}).text.strip())
            phone.append(soup.find(attrs={'class': 'biz-phone'}).text.strip())
            
            if soup.find("a", href=lambda href: href and "biz_redir?" in href) is not None:
                website.append(soup.find("a", href=lambda href: href and "biz_redir?" in href).text.strip())
            else:
                website.append('no website')
        
        except:
            business_name.append('unavailable')
            business_category.append('unavailable')
            yelp_rating.append('unavailable')
            review_count.append('unavailable')
            price_range.append('unavailable')
            price_category.append('unavailable')
            address.append('unavailable')
            phone.append('unavailable')
            website.append('unavailable')
            continue

# %%
# create a dataframe with yelp data from yelp scrape

def create_table():
    data = {
    'BusinessName' : business_name,
    'BusinessCategory' : business_category,
    'YelpRating' : yelp_rating,
    'ReviewCount' : review_count,
    'PriceRange($)' : price_range,
    'PriceCategory': price_category,
    'Address' : address, 
    'Phone' : phone,
    'Website' : website
        
    }
    # return data
    df = pd.DataFrame.from_dict(data)
    df = df[['BusinessName','BusinessCategory','YelpRating','ReviewCount','PriceRange($)', 'PriceCategory','Address',
            'Phone', 'Website']]
    df.to_csv(f'../data/yelp_{search}{zipcode}.csv')
    return df

# %%
# RUN FUNCTION
search_yelp(search, zipcode)

# %%
# RUN FUNCTION
scrape_yelp(url)

# %%
# RUN FUNCTION
create_table()
# Out:
#                     BusinessName  \
# 0           Justin’s Barber Shop
# 1                       i Barber
# 2                  Modern Barber
# 3            Louie’s Barber Shop
# 4         Affiliated Barber Shop
# 5         Black Steel Barbershop
# 6        Good Fellaz Barber Shop
# 7            George’s Barbershop
# 8            American Barbershop
# 9            Santana Barber Shop
# 10           Plaza Barber Center
# 11            4 Aces Barber Shop
# 12         Floyd’s 99 Barbershop
# 13          PrimeTime Barbershop
# 14               Omar the Barber
# 15  Stonecreek Plaza Barber Shop
# 16      The Main Cave Barbershop
# 17       Vatican Barbershop VTCN
# 18      Blazing Fades Barbershop
# 19          El Catrin Barbershop
#
#                                    BusinessCategory       YelpRating  \
# 0                                           Barbers  4.5 star rating
# 1                                           Barbers  4.5 star rating
# 2                                           Barbers  4.5 star rating
# 3                                           Barbers  4.5 star rating
# 4                                           Barbers  4.5 star rating
# 5                                           Barbers  4.5 star rating
# 6                                           Barbers  4.5 star rating
# 7                                           Barbers  4.5 star rating
# 8                                           Barbers  4.0 star rating
# 9                                           Barbers  4.0 star rating
# 10                                          Barbers  3.5 star rating
# 11                                          Barbers  5.0 star rating
# 12  Barbers,\n                    Men's Hair Salons  4.0 star rating
# 13                                          Barbers  3.5 star rating
# 14                                          Barbers  4.5 star rating
# 15                                          Barbers  5.0 star rating
# 16                                          Barbers  4.5 star rating
# 17                                          Barbers  4.5 star rating
# 18                                          Barbers  4.0 star rating
# 19                                          Barbers  4.5 star rating
#
#     ReviewCount PriceRange($) PriceCategory  \
# 0   148 reviews             $   Inexpensive
# 1   144 reviews             $   Inexpensive
# 2   143 reviews            $$      Moderate
# 3    26 reviews             $   Inexpensive
# 4   190 reviews            $$      Moderate
# 5    47 reviews            $$      Moderate
# 6   251 reviews            $$      Moderate
# 7    38 reviews             $   Inexpensive
# 8   234 reviews            $$      Moderate
# 9    11 reviews             $   Inexpensive
# 10   13 reviews             $   Inexpensive
# 11   33 reviews             $   Inexpensive
# 12  161 reviews            $$      Moderate
# 13   25 reviews             $   Inexpensive
# 14  305 reviews             $   Inexpensive
# 15  137 reviews             $   Inexpensive
# 16   25 reviews            $$      Moderate
# 17   75 reviews            $$      Moderate
# 18   61 reviews            $$      Moderate
# 19  169 reviews            $$      Moderate
#
#                                           Address           Phone  \
# 0          13762 Newport AveSte BTustin, CA 92780  (714) 852-3902
# 1                   622 E 1st AveTustin, CA 92780  (714) 760-4091
# 2                    139 W 1st StTustin, CA 92780  (714) 838-8621
# 3                    414 E 1st StTustin, CA 92780  (714) 731-9119
# 4        2521 N Grand AveSte ESanta Ana, CA 92705  (714) 805-1431
# 5                          Located inUnion Market  (949) 239-8937
# 6                617 W 17th StSanta Ana, CA 92706  (657) 600-8551
# 7           2315 17th StUnit 1Santa Ana, CA 92705  (714) 333-7239
# 8                 320 E 4th StSanta Ana, CA 92701  (714) 550-7430
# 9                 826 E 4th StSanta Ana, CA 92701  (714) 875-0368
# 10                1072 Walnut AveTustin, CA 92780  (714) 544-2964
# 11             3122 E Chapman AveOrange, CA 92869  (657) 262-1002
# 12           12872 Newport AvenueTustin, CA 92780  (714) 509-5830
# 13              1911 S Main StSanta Ana, CA 92707  (714) 850-1878
# 14  13925 Yale AveKija Hair SalonIrvine, CA 92620  (714) 618-1133
# 15                     Located inStonecreek Plaza  (949) 786-6404
# 16               307 N Main StSanta Ana, CA 92701  (657) 245-3324
# 17         103 E City Place DrSanta Ana, CA 92705  (657) 247-0247
# 18            2705 N Grand AveSanta Ana, CA 92705  (714) 943-4643
# 19           400 W 4th StSte BSanta Ana, CA 92701  (714) 558-3948
#
#                            Website
# 0                       no website
# 1                       no website
# 2                 modernbarber.net
# 3                       no website
# 4                       no website
# 5         blacksteelbarbershop.com
# 6         goodfellazbarbershop.com
# 7                       no website
# 8           americanbarbershop.com
# 9                       no website
# 10                      no website
# 11  4-aces-barber-shop.business.s…
# 12            floydsbarbershop.com
# 13                      no website
# 14               omarthebarber.com
# 15   stonecreekplazabarbershop.com
# 16                      no website
# 17                vtcn.resurva.com
# 18      blazingfadesbarbershop.com
# 19            barberiaelcatrin.com
