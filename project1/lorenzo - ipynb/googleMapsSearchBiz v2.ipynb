# %%
# Dependencies
import pandas as pd
import numpy as np
from numpy import nan as Nan
import requests
import json
import re

# Google developer API key
gkey = "AIzaSyDbW3R50-rJm1kDS5AcAfMd0gSrpRB9wko"

# %%
gsearch = input("What would you like to search?")
# Out:
# What would you like to search?barbershops

# %%
gsearch
# Out:
# 'barbershops'

# %% [markdown]
# # find the closest restaurant of each type to coordinates
#
# base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
# params = {
#     "location": "33.66946, -117.82311",  # Irvine coords,
#     "rankby":"distance",
#     "type":"hair_care",
#     "key": gkey
# }
#
# response = requests.get(base_url, params)
# print(response.url)

# %%
# find the closest restaurant of each type to coordinates

base_url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"
params = {
    "location": "33.66946, -117.82311",  # Irvine coords,
    "rankby":"distance",
    "type":"hair_care",
    "keyword": gsearch,
    "key": gkey
}

 # assemble url and make API request
print(f"Retrieving Results for: {gsearch}.")
response = requests.get(base_url, params=params)
url = response.url
print(response.url)
print("============================================")
# Out:
# Retrieving Results for: barbershops.
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?location=33.66946%2C+-117.82311&rankby=distance&type=hair_care&keyword=barbershops&key=AIzaSyDbW3R50-rJm1kDS5AcAfMd0gSrpRB9wko
# ============================================

# %%
df = json.loads(requests.get(url).text)
list(df.keys())
# Out:
# ['html_attributions', 'next_page_token', 'results', 'status']

# %%
googleDF = pd.DataFrame(df["results"])

# %%
googleDF = googleDF[['geometry','name','rating','types','vicinity']]

# %%
googleDF.columns = ['Geometry','Business Name','Rating','Business Types','Address']

# %%
googleDF.to_csv(f'../data/{gsearch}_google.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-79-6b6f6c68453c> in <module>()
# ----> 1 googleDF.to_csv(f'../data/{gsearch}_google.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1401                                      doublequote=doublequote,
#    1402                                      escapechar=escapechar, decimal=decimal)
# -> 1403         formatter.save()
#    1404
#    1405         if path_or_buf is None:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in save(self)
#    1575             f, handles = _get_handle(self.path_or_buf, self.mode,
#    1576                                      encoding=self.encoding,
# -> 1577                                      compression=self.compression)
#    1578             close = True
#    1579
#
# ~\Anaconda3\lib\site-packages\pandas\io\common.py in _get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     383         elif is_text:
#     384             # Python 3 and no explicit encoding
# --> 385             f = open(path_or_buf, mode, errors='replace')
#     386         else:
#     387             # Python 3 and binary mode
#
# PermissionError: [Errno 13] Permission denied: '../data/barbershops_google.csv'

# %%
googleDF.head()
# Out:
#                                             Geometry  \
# 0  {'location': {'lat': 33.6850424, 'lng': -117.8...
# 1  {'location': {'lat': 33.6806996, 'lng': -117.8...
# 2  {'location': {'lat': 33.680738, 'lng': -117.80...
# 3  {'location': {'lat': 33.6976351, 'lng': -117.8...
# 4  {'location': {'lat': 33.6710241, 'lng': -117.7...
#
#                                        Business Name  Rating  \
# 0                              Floyd's 99 Barbershop     3.9
# 1  Stonecreek Plaza Barber Shop (inside H&R Block...     4.9
# 2                        Justin's Fade's&Hairstyle's     5.0
# 3                             Black Steel Barbershop     4.0
# 4                     Roosters Men's Grooming Center     4.4
#
#                                       Business Types  \
# 0  [beauty_salon, hair_care, health, point_of_int...
# 1  [hair_care, health, point_of_interest, establi...
# 2  [hair_care, health, point_of_interest, establi...
# 3  [hair_care, health, point_of_interest, establi...
# 4  [hair_care, health, point_of_interest, establi...
#
#                            Address
# 0     3972 Barranca Pkwy H, Irvine
# 1  4330 Barranca Pkwy #105, Irvine
# 2       4330 Barranca Pkwy, Irvine
# 3        2493 Park Ave #28, Tustin
# 4          5405 Alton Pkwy, Irvine

# %%
latlong = googleDF['Geometry']

# %%
location = []

for i in latlong:
    location.append(i['location'])

# %%
gDF = pd.DataFrame(location)
gDF
# Out:
#           lat         lng
# 0   33.685042 -117.810495
# 1   33.680700 -117.803782
# 2   33.680738 -117.803632
# 3   33.697635 -117.827587
# 4   33.671024 -117.788047
# 5   33.686957 -117.858372
# 6   33.656782 -117.864477
# 7   33.668401 -117.764456
# 8   33.658477 -117.885429
# 9   33.705033 -117.772796
# 10  33.655617 -117.903723
# 11  33.677690 -117.918946
# 12  33.750281 -117.809419
# 13  33.747891 -117.864626
# 14  33.637171 -117.920873
# 15  33.747653 -117.870966
# 16  33.745771 -117.880408
# 17  33.757973 -117.867210
# 18  33.770604 -117.851762
# 19  33.773696 -117.851987

# %%
googleLatLong = googleDF.join(gDF)
googleLatLong
# Out:
#                                              Geometry  \
# 0   {'location': {'lat': 33.6850424, 'lng': -117.8...
# 1   {'location': {'lat': 33.6806996, 'lng': -117.8...
# 2   {'location': {'lat': 33.680738, 'lng': -117.80...
# 3   {'location': {'lat': 33.6976351, 'lng': -117.8...
# 4   {'location': {'lat': 33.6710241, 'lng': -117.7...
# 5   {'location': {'lat': 33.6869575, 'lng': -117.8...
# 6   {'location': {'lat': 33.656782, 'lng': -117.86...
# 7   {'location': {'lat': 33.668401, 'lng': -117.76...
# 8   {'location': {'lat': 33.6584767, 'lng': -117.8...
# 9   {'location': {'lat': 33.7050333, 'lng': -117.7...
# 10  {'location': {'lat': 33.6556174, 'lng': -117.9...
# 11  {'location': {'lat': 33.6776904, 'lng': -117.9...
# 12  {'location': {'lat': 33.7502815, 'lng': -117.8...
# 13  {'location': {'lat': 33.7478909, 'lng': -117.8...
# 14  {'location': {'lat': 33.637171, 'lng': -117.92...
# 15  {'location': {'lat': 33.7476529, 'lng': -117.8...
# 16  {'location': {'lat': 33.7457715, 'lng': -117.8...
# 17  {'location': {'lat': 33.757973, 'lng': -117.86...
# 18  {'location': {'lat': 33.770604, 'lng': -117.85...
# 19  {'location': {'lat': 33.7736955, 'lng': -117.8...
#
#                                         Business Name  Rating  \
# 0                               Floyd's 99 Barbershop     3.9
# 1   Stonecreek Plaza Barber Shop (inside H&R Block...     4.9
# 2                         Justin's Fade's&Hairstyle's     5.0
# 3                              Black Steel Barbershop     4.0
# 4                      Roosters Men's Grooming Center     4.4
# 5                        Creations Salon & Barbershop     4.7
# 6                                           Supercuts     3.6
# 7                                  Sand Canyon Barber     4.3
# 8                               True Blue Barber Shop     4.3
# 9                                           Danckut's     4.7
# 10                         Aces And Eights Barbershop     5.0
# 11                              Floyd's 99 Barbershop     3.9
# 12                              Floyd's 99 Barbershop     4.4
# 13                                American Barbershop     4.2
# 14                              Floyd's 99 Barbershop     4.2
# 15                               El Catrin BarberShop     4.6
# 16                     Muñoz Barbershop And Hairsalon     5.0
# 17                               NUMBER #1 Barbershop     3.9
# 18                              Affiliated barbershop     4.3
# 19                           Blazing Fades Barbershop     4.7
#
#                                        Business Types  \
# 0   [beauty_salon, hair_care, health, point_of_int...
# 1   [hair_care, health, point_of_interest, establi...
# 2   [hair_care, health, point_of_interest, establi...
# 3   [hair_care, health, point_of_interest, establi...
# 4   [hair_care, health, point_of_interest, establi...
# 5   [hair_care, health, point_of_interest, establi...
# 6   [beauty_salon, hair_care, health, point_of_int...
# 7   [hair_care, health, point_of_interest, establi...
# 8   [hair_care, health, point_of_interest, establi...
# 9   [hair_care, health, point_of_interest, establi...
# 10  [hair_care, health, point_of_interest, establi...
# 11  [beauty_salon, hair_care, health, point_of_int...
# 12  [beauty_salon, hair_care, health, point_of_int...
# 13  [hair_care, health, point_of_interest, establi...
# 14  [beauty_salon, hair_care, store, health, point...
# 15  [hair_care, health, point_of_interest, establi...
# 16  [hair_care, health, point_of_interest, establi...
# 17  [hair_care, health, point_of_interest, establi...
# 18  [hair_care, health, point_of_interest, establi...
# 19  [hair_care, health, point_of_interest, establi...
#
#                                       Address        lat         lng
# 0                3972 Barranca Pkwy H, Irvine  33.685042 -117.810495
# 1             4330 Barranca Pkwy #105, Irvine  33.680700 -117.803782
# 2                  4330 Barranca Pkwy, Irvine  33.680738 -117.803632
# 3                   2493 Park Ave #28, Tustin  33.697635 -117.827587
# 4                     5405 Alton Pkwy, Irvine  33.671024 -117.788047
# 5                       17779 Main St, Irvine  33.686957 -117.858372
# 6         3601 Jamboree Rd #18, Newport Beach  33.656782 -117.864477
# 7               6642 Irvine Center Dr, Irvine  33.668401 -117.764456
# 8                 2675 Irvine Ave, Costa Mesa  33.658477 -117.885429
# 9                 185 13925, Yale Ave, Irvine  33.705033 -117.772796
# 10     2346, ste b2, Newport Blvd, Costa Mesa  33.655617 -117.903723
# 11               2900 Harbor Blvd, Costa Mesa  33.677690 -117.918946
# 12                  12872 Newport Ave, Tustin  33.750281 -117.809419
# 13                  320 E 4th St a, Santa Ana  33.747891 -117.864626
# 14                  124 E 17th St, Costa Mesa  33.637171 -117.920873
# 15                    400 W 4th St, Santa Ana  33.747653 -117.870966
# 16                 1055 C W 1st St, Santa Ana  33.745771 -117.880408
# 17                  1501 N Main St, Santa Ana  33.757973 -117.867210
# 18  2525-2521 North Grand Avenue e, Santa Ana  33.770604 -117.851762
# 19                2705 N Grand Ave, Santa Ana  33.773696 -117.851987

# %%
googleLatLong = googleLatLong[['lat','lng','Business Name','Rating','Business Types','Address']]

# %%
googleLatLong.columns =
# Out:
#           lat         lng                                      Business Name  \
# 0   33.685042 -117.810495                              Floyd's 99 Barbershop
# 1   33.680700 -117.803782  Stonecreek Plaza Barber Shop (inside H&R Block...
# 2   33.680738 -117.803632                        Justin's Fade's&Hairstyle's
# 3   33.697635 -117.827587                             Black Steel Barbershop
# 4   33.671024 -117.788047                     Roosters Men's Grooming Center
# 5   33.686957 -117.858372                       Creations Salon & Barbershop
# 6   33.656782 -117.864477                                          Supercuts
# 7   33.668401 -117.764456                                 Sand Canyon Barber
# 8   33.658477 -117.885429                              True Blue Barber Shop
# 9   33.705033 -117.772796                                          Danckut's
# 10  33.655617 -117.903723                         Aces And Eights Barbershop
# 11  33.677690 -117.918946                              Floyd's 99 Barbershop
# 12  33.750281 -117.809419                              Floyd's 99 Barbershop
# 13  33.747891 -117.864626                                American Barbershop
# 14  33.637171 -117.920873                              Floyd's 99 Barbershop
# 15  33.747653 -117.870966                               El Catrin BarberShop
# 16  33.745771 -117.880408                     Muñoz Barbershop And Hairsalon
# 17  33.757973 -117.867210                               NUMBER #1 Barbershop
# 18  33.770604 -117.851762                              Affiliated barbershop
# 19  33.773696 -117.851987                           Blazing Fades Barbershop
#
#     Rating                                     Business Types  \
# 0      3.9  [beauty_salon, hair_care, health, point_of_int...
# 1      4.9  [hair_care, health, point_of_interest, establi...
# 2      5.0  [hair_care, health, point_of_interest, establi...
# 3      4.0  [hair_care, health, point_of_interest, establi...
# 4      4.4  [hair_care, health, point_of_interest, establi...
# 5      4.7  [hair_care, health, point_of_interest, establi...
# 6      3.6  [beauty_salon, hair_care, health, point_of_int...
# 7      4.3  [hair_care, health, point_of_interest, establi...
# 8      4.3  [hair_care, health, point_of_interest, establi...
# 9      4.7  [hair_care, health, point_of_interest, establi...
# 10     5.0  [hair_care, health, point_of_interest, establi...
# 11     3.9  [beauty_salon, hair_care, health, point_of_int...
# 12     4.4  [beauty_salon, hair_care, health, point_of_int...
# 13     4.2  [hair_care, health, point_of_interest, establi...
# 14     4.2  [beauty_salon, hair_care, store, health, point...
# 15     4.6  [hair_care, health, point_of_interest, establi...
# 16     5.0  [hair_care, health, point_of_interest, establi...
# 17     3.9  [hair_care, health, point_of_interest, establi...
# 18     4.3  [hair_care, health, point_of_interest, establi...
# 19     4.7  [hair_care, health, point_of_interest, establi...
#
#                                       Address
# 0                3972 Barranca Pkwy H, Irvine
# 1             4330 Barranca Pkwy #105, Irvine
# 2                  4330 Barranca Pkwy, Irvine
# 3                   2493 Park Ave #28, Tustin
# 4                     5405 Alton Pkwy, Irvine
# 5                       17779 Main St, Irvine
# 6         3601 Jamboree Rd #18, Newport Beach
# 7               6642 Irvine Center Dr, Irvine
# 8                 2675 Irvine Ave, Costa Mesa
# 9                 185 13925, Yale Ave, Irvine
# 10     2346, ste b2, Newport Blvd, Costa Mesa
# 11               2900 Harbor Blvd, Costa Mesa
# 12                  12872 Newport Ave, Tustin
# 13                  320 E 4th St a, Santa Ana
# 14                  124 E 17th St, Costa Mesa
# 15                    400 W 4th St, Santa Ana
# 16                 1055 C W 1st St, Santa Ana
# 17                  1501 N Main St, Santa Ana
# 18  2525-2521 North Grand Avenue e, Santa Ana
# 19                2705 N Grand Ave, Santa Ana
